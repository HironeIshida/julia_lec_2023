# %%
using Plots

# %%
f(x) = x^2
# Out:
# f (generic function with 1 method)

# %%
res = []
for N in 1:25

    xlim = range(0, 1, length = 2^N)
    S = 0

    for x in xlim
        S += f(x)/2^N
    end

    S = abs((1/3)-S)

    push!(res, S)
end

plot(res, yaxis = :log)

# %%
x = [1, 2, 3, 4, 5]
y = x.^2
# Out:
# 5-element Vector{Int64}:
#   1
#   4
#   9
#  16
#  25
